# %%
#Import dependencies
import matplotlib.pyplot as plt
import pandas as pd

# %%
#read census file
census = pd.read_csv("state_census_data.csv")
census.head()
# Out:
#           Name  Household Income  Population  Median Age  Median Male Age  \
# 0  ZCTA5 00601           13092.0     17242.0        40.5             39.5
# 1  ZCTA5 00602           16358.0     38442.0        42.3             41.9
# 2  ZCTA5 00603           16603.0     48814.0        41.1             39.1
# 3  ZCTA5 00606           12832.0      6437.0        43.3             43.2
# 4  ZCTA5 00610           19309.0     27073.0        42.1             40.4
#
#    Median Female Age  Per Capita Income  Zipcode  Zip  lat  lng  city  \
# 0               41.3             6999.0      601  NaN  NaN  NaN   NaN
# 1               42.8             9277.0      602  NaN  NaN  NaN   NaN
# 2               42.9            11307.0      603  NaN  NaN  NaN   NaN
# 3               43.4             5943.0      606  NaN  NaN  NaN   NaN
# 4               44.2            10220.0      610  NaN  NaN  NaN   NaN
#
#    state_id  State
# 0       NaN    NaN
# 1       NaN    NaN
# 2       NaN    NaN
# ...

# %%
#clean the data - some rows have income as -666666666.0
census_clean = census.loc[census[""]]

# %%
#create box plot of median age vs per capita income
#axis = ["Median age", "Per capita income"]
age = census[["Median Age"]]
#age_clean = age.loc[["Median Age"] >= -666666666.0]
# fig1, ax1 = plt.subplots()
# # ax5.set_title("Final tumor volume across four regimens")
# # ax5.set_ylabel("Tumor Volume (mm3)")
plt.boxplot(age, showfliers=True)
plt.tight_layout()
age
# Out:
#         Median Age
# 0             40.5
# 1             42.3
# 2             41.1
# 3             43.3
# 4             42.1
# ...            ...
# 33115         44.2
# 33116 -666666666.0
# 33117         36.0
# 33118         48.0
# 33119         39.3
#
# [33120 rows x 1 columns]

# %%
income = census[["Per Capita Income"]]
#fig2, ax2 = plt.subplots()
plt.boxplot(income, showfliers=True)
plt.tight_layout()
plt.show()
income
# Out:
#        Per Capita Income
# 0                 6999.0
# 1                 9277.0
# 2                11307.0
# 3                 5943.0
# 4                10220.0
# ...                  ...
# 33115                NaN
# 33116                NaN
# 33117                NaN
# 33118                NaN
# 33119                NaN
#
# [33120 rows x 1 columns]
