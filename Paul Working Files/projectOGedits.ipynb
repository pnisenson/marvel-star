# %% [markdown]
# # Dependencies

# %%
# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests #This is used to request information from the API

# %% [markdown]
# # Performing Json.get request

# %%
# Specify the URL

request = requests.get("https://mcuapi.herokuapp.com/api/v1/movies")
request_text = request.text
data = json.loads(request_text)
#print(data)
print(data["data"][3]["title"])
print(data)
# Out:
# Thor
# {'data': [{'id': 1, 'title': 'Iron Man', 'release_date': '2008-05-02', 'box_office': '585171547', 'duration': 126, 'overview': "2008's Iron Man tells the story of Tony Stark, a billionaire industrialist and genius inventor who is kidnapped and forced to build a devastating weapon. Instead, using his intelligence and ingenuity, Tony builds a high-tech suit of armor and escapes captivity. When he uncovers a nefarious plot with global implications, he dons his powerful armor and vows to protect the world as Iron Man.", 'cover_url': 'https://raw.githubusercontent.com/AugustoMarcelo/mcuapi/master/covers/iron-man.jpg', 'trailer_url': 'http://players.brightcove.net/5359769168001/BJemW31x6g_default/index.html?videoId=5786306590001', 'directed_by': 'Jon Favreau', 'phase': 1, 'saga': 'Infinity Saga', 'chronology': 3, 'post_credit_scenes': 1}, {'id': 2, 'title': 'The Incredible Hulk', 'release_date': '2008-06-13', 'box_office': '265573859', 'duration': 112, 'overview': "In this new beginning, scientist Bruce Banner desperately hunts for a cure to the gamma radiation that poisoned his cells and unleashes the unbridled force of rage within him: The Hulk. Living in the shadows--cut off from a life he knew and the woman he loves, Betty Ross--Banner struggles to avoid the obsessive pursuit of his nemesis, General Thunderbolt Ross and the military machinery that seeks to capture him and brutally exploit his power. As all three grapple with the secrets that led to the Hulk's creation, they are confronted with a monstrous new adversary known as the Abomination, whose destructive strength exceeds even the Hulk's own. One scientist must make an agonizing final choice: accept a peaceful life as Bruce Banner or find heroism in the creature he holds inside--The Incredible Hulk.", 'cover_url': 'https://raw.githubusercontent.com/AugustoMarcelo/mcuapi/master/covers/hulk.jpg', 'trailer_url': 'http://players.brightcove.net/5359769168001/rkg9u15t7b_default/index.html?videoId=5786823800001', 'directed_by': 'Louis Leterrier', 'phase': 1, 'saga': 'Infinity Saga', 'chronology': 5, 'post_credit_scenes': 1}, {'id': 3, 'title': 'Iron Man 2', 'release_date': '2010-05-07', 'box_office': '621156389', 'duration': 124, 'overview': 'With the world now aware that he is Iron Man, billionaire inventor Tony Stark faces pressure from all sides to share his technology with the military. He is reluctant to divulge the secrets of his armored suit, fearing the information will fall into the wrong hands. With Pepper Potts and "Rhodey" Rhodes by his side, Tony must forge new alliances and confront a powerful new enemy.', 'cover_url': 'https://raw.githubusercontent.com/AugustoMarcelo/mcuapi/master/covers/iron-man-2.jpg', 'trailer_url': 'http://players.brightcove.net/5359769168001/BJemW31x6g_default/index.html?videoId=5786616628001', 'directed_by': 'Jon Favreau', 'phase': 1, 'saga': 'Infinity Saga', 'chronology': 4, 'post_credit_scenes': 1}, {'id': 4, 'title': 'Thor', 'release_date': '2011-05-06', 'box_office': '449326618', 'duration': 115, 'overview': "As the son of Odin, king of the Norse gods, Thor will soon inherit the throne of Asgard from his aging father. However, on the day that he is to be crowned, Thor reacts with brutality when the gods' enemies, the Frost Giants, enter the palace in violation of their treaty. As punishment, Odin banishes Thor to Earth. While Loki, Thor's brother, plots mischief in Asgard, Thor, now stripped of his powers, faces his greatest threat.", 'cover_url': 'https://raw.githubusercontent.com/AugustoMarcelo/mcuapi/master/covers/thor.jpg', 'trailer_url': 'http://players.brightcove.net/5359769168001/rkg9u15t7b_default/index.html?videoId=5806335470001', 'directed_by': 'Kenneth Branagh', 'phase': 1, 'saga': 'Infinity Saga', 'chronology': 6, 'post_credit_scenes': 1}, {'id': 5, 'title': 'Captain America: The First Avenger', 'release_date': '2011-07-22', 'box_office': '370569776', 'duration': 124, 'overview': "Marvel's 'Captain America: The First Avenger' ...

# %% [markdown]
# # Creating Roles and Columns

# %%
release_date = []
chronology = []
title = [] 
box_office = []
duration = []

for movies in range(0,28):
    release_date.append(data["data"][movies]["release_date"])
    title.append(data["data"][movies]["title"])
    chronology.append(data["data"][movies]["chronology"])
    box_office.append(data["data"][movies]["box_office"])
    duration.append(data["data"][movies]["duration"])

    
movies_list = pd.DataFrame({"Title": title,
                            "Box Office (in 000s)": box_office,
                            "Release Date": release_date,
                            "Chronology":chronology,
                            "Duration":duration
                            
})   
movies_list["Box Office (in 000s)"] = movies_list["Box Office (in 000s)"].astype(float) / 1000
movies_list["Release Date"] = pd.to_datetime(movies_list["Release Date"])
movies_list
# Out:
#                                           Title  Box Office (in 000s)  \
# 0                                      Iron Man            585171.547
# 1                           The Incredible Hulk            265573.859
# 2                                    Iron Man 2            621156.389
# 3                                          Thor            449326.618
# 4            Captain America: The First Avenger            370569.776
# 5                                  The Avengers           1517935.897
# 6                                    Iron Man 3           1215392.272
# 7                          Thor: The Dark World            644602.516
# 8           Captain America: The Winter Soldier            714401.889
# 9                       Guardians of the Galaxy            770867.516
# 10                      Avengers: Age of Ultron           1403013.963
# 11                                      Ant-Man            518858.449
# 12                   Captain America: Civil War           1140069.413
# 13                               Doctor Strange            676404.566
# 14               Guardians of the Galaxy Vol. 2            862316.233
# 15                       Spider-Man: Homecoming            880166.350
# 16                               Thor: Ragnarok            846980.024
# 17                                Black Panther           1348258.224
# 18                       Avengers: Infinity War           2048134.200
# 19                         Ant-Man and The Wasp            623144.660
# 20                               Captain Marvel           1126129.839
# 21                            Avengers: Endgame           2795465.685
# 22                    Spider-Man: Far From Home           1123901.180
# 23                                  Black Widow                 0.000
# 24                                 The Eternals                 0.000
# 25    Shang-Chi and the Legend of the Ten Rings                 0.000
# 26  Doctor Strange in the Multiverse of Madness                 0.000
# 27                       Thor: Love and Thunder                 0.000
#
#    Release Date  Chronology  Duration
# 0    2008-05-02         3.0       126
# 1    2008-06-13         5.0       112
# 2    2010-05-07         4.0       124
# 3    2011-05-06         6.0       115
# 4    2011-07-22         1.0       124
# 5    2012-05-04         7.0       143
# 6    2013-05-03         8.0       130
# 7    2013-11-08         9.0       112
# 8    2014-04-04        10.0       136
# 9    2014-08-01        11.0       121
# 10   2015-05-01        13.0       141
# 11   2015-07-17        14.0       117
# 12   2016-05-06        15.0       147
# 13   2016-11-04        18.0       115
# 14   2017-05-05        12.0       136
# 15   2017-07-07        17.0       133
# 16   2017-11-03        19.0       130
# 17   2018-02-16        16.0       134
# 18   2018-04-27        20.0       149
# 19   2018-07-06        21.0       125
# 20   2019-03-08         2.0       125
# 21   2019-04-26        22.0       182
# 22   2019-07-02        23.0       129
# 23   2020-11-06         NaN         0
# 24   2021-02-12         NaN         0
# 25   2021-05-07         NaN         0
# 26   2022-03-25         NaN         0
# 27   2022-02-11         NaN         0

# %% [markdown]
# # Dropping $0 Values

# %%
#Dropping $0 box office - movies haven't been released, ignore for analysis
released_movies = movies_list.loc[movies_list["Box Office (in 000s)"]> 0]
released_movies = released_movies.sort_values(['Box Office (in 000s)'], ascending = False)
released_movies.to_csv("marvel_files/final_movies.csv") 
released_movies
# Out:
#                                   Title  Box Office (in 000s) Release Date  \
# 21                    Avengers: Endgame           2795465.685   2019-04-26
# 18               Avengers: Infinity War           2048134.200   2018-04-27
# 5                          The Avengers           1517935.897   2012-05-04
# 10              Avengers: Age of Ultron           1403013.963   2015-05-01
# 17                        Black Panther           1348258.224   2018-02-16
# 6                            Iron Man 3           1215392.272   2013-05-03
# 12           Captain America: Civil War           1140069.413   2016-05-06
# 20                       Captain Marvel           1126129.839   2019-03-08
# 22            Spider-Man: Far From Home           1123901.180   2019-07-02
# 15               Spider-Man: Homecoming            880166.350   2017-07-07
# 14       Guardians of the Galaxy Vol. 2            862316.233   2017-05-05
# 16                       Thor: Ragnarok            846980.024   2017-11-03
# 9               Guardians of the Galaxy            770867.516   2014-08-01
# 8   Captain America: The Winter Soldier            714401.889   2014-04-04
# 13                       Doctor Strange            676404.566   2016-11-04
# 7                  Thor: The Dark World            644602.516   2013-11-08
# 19                 Ant-Man and The Wasp            623144.660   2018-07-06
# 2                            Iron Man 2            621156.389   2010-05-07
# 0                              Iron Man            585171.547   2008-05-02
# 11                              Ant-Man            518858.449   2015-07-17
# 3                                  Thor            449326.618   2011-05-06
# 4    Captain America: The First Avenger            370569.776   2011-07-22
# 1                   The Incredible Hulk            265573.859   2008-06-13
#
#     Chronology  Duration
# 21        22.0       182
# 18        20.0       149
# 5          7.0       143
# 10        13.0       141
# 17        16.0       134
# 6          8.0       130
# 12        15.0       147
# 20         2.0       125
# 22        23.0       129
# 15        17.0       133
# 14        12.0       136
# 16        19.0       130
# 9         11.0       121
# 8         10.0       136
# 13        18.0       115
# 7          9.0       112
# 19        21.0       125
# 2          4.0       124
# 0          3.0       126
# 11        14.0       117
# 3          6.0       115
# 4          1.0       124
# 1          5.0       112

# %%
#Formating Box Office - this version cannot be used in plotting due to formatting
final_movies = released_movies.copy()
final_movies ["Box Office (in 000s)"] = final_movies ["Box Office (in 000s)"].map("${:,.2f}".format)
final_movies
# Out:
#                                   Title Box Office (in 000s) Release Date  \
# 21                    Avengers: Endgame        $2,795,465.69   2019-04-26
# 18               Avengers: Infinity War        $2,048,134.20   2018-04-27
# 5                          The Avengers        $1,517,935.90   2012-05-04
# 10              Avengers: Age of Ultron        $1,403,013.96   2015-05-01
# 17                        Black Panther        $1,348,258.22   2018-02-16
# 6                            Iron Man 3        $1,215,392.27   2013-05-03
# 12           Captain America: Civil War        $1,140,069.41   2016-05-06
# 20                       Captain Marvel        $1,126,129.84   2019-03-08
# 22            Spider-Man: Far From Home        $1,123,901.18   2019-07-02
# 15               Spider-Man: Homecoming          $880,166.35   2017-07-07
# 14       Guardians of the Galaxy Vol. 2          $862,316.23   2017-05-05
# 16                       Thor: Ragnarok          $846,980.02   2017-11-03
# 9               Guardians of the Galaxy          $770,867.52   2014-08-01
# 8   Captain America: The Winter Soldier          $714,401.89   2014-04-04
# 13                       Doctor Strange          $676,404.57   2016-11-04
# 7                  Thor: The Dark World          $644,602.52   2013-11-08
# 19                 Ant-Man and The Wasp          $623,144.66   2018-07-06
# 2                            Iron Man 2          $621,156.39   2010-05-07
# 0                              Iron Man          $585,171.55   2008-05-02
# 11                              Ant-Man          $518,858.45   2015-07-17
# 3                                  Thor          $449,326.62   2011-05-06
# 4    Captain America: The First Avenger          $370,569.78   2011-07-22
# 1                   The Incredible Hulk          $265,573.86   2008-06-13
#
#     Chronology  Duration
# 21        22.0       182
# 18        20.0       149
# 5          7.0       143
# 10        13.0       141
# 17        16.0       134
# 6          8.0       130
# 12        15.0       147
# 20         2.0       125
# 22        23.0       129
# 15        17.0       133
# 14        12.0       136
# 16        19.0       130
# 9         11.0       121
# 8         10.0       136
# 13        18.0       115
# 7          9.0       112
# 19        21.0       125
# 2          4.0       124
# 0          3.0       126
# 11        14.0       117
# 3          6.0       115
# 4          1.0       124
# 1          5.0       112

# %%
# box office earnings over time
TimeBox = released_movies.plot(kind = "line", x = "Release Date", y = "Box Office (in 000s)", color = "red", grid = True)
TimeBox.set_ylabel("Box Office (in millions)", fontsize = 15, color = "black")
TimeBox.set_xlabel("Release Date", fontsize = 15, color = "black")
plt.show()

# %%
EarnBar = released_movies.plot(kind = "bar", x = "Title", y = "Box Office (in 000s)", color = "red")
EarnBar.set_ylabel("Box Office (in millions)", fontsize = 15, color = "black")
EarnBar.set_xlabel("Movie Title", fontsize = 15, color = "black")
plt.show()
