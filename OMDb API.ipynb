# %%
#Dependencies
import requests
import json
import pandas as pd
import numpy as np
from config import api_key
from pprint import pprint
#api_key
# Out:
# '43b8d062'

# %%
movies = pd.read_csv("Marvel movies.csv", encoding = "ISO-8859-1")
movies.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-25-0c976a0b431b> in <module>
# ----> 1 movies = pd.read_csv("Marvel movies.csv", encoding = "ISO-8859-1")
#       2 movies.head()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 8, saw 3

# %%
#OMDb api key
url = f"http://www.omdbapi.com/?apikey={api_key}&t="
responses = []
movie_list = ["X-Men", "Spider-Man", "Iron Man", "Thor"]

# for movie in movie_list:
# response = requests.get(url + "Marvel").json()
for movie in movie_list:
    movie_data = requests.get(url + movie).json()
    responses.append(movie_data)
    responses

# %%
movie_df = pd.DataFrame(responses)
movie_df
# Out:
#         Title  Year  Rated     Released  Runtime                       Genre  \
# 0       X-Men  2000  PG-13  14 Jul 2000  104 min   Action, Adventure, Sci-Fi
# 1  Spider-Man  2002  PG-13  03 May 2002  121 min   Action, Adventure, Sci-Fi
# 2    Iron Man  2008  PG-13  02 May 2008  126 min   Action, Adventure, Sci-Fi
# 3        Thor  2011  PG-13  06 May 2011  115 min  Action, Adventure, Fantasy
#
#           Director                                             Writer  \
# 0     Bryan Singer  Tom DeSanto (story), Bryan Singer (story), Dav...
# 1        Sam Raimi  Stan Lee (Marvel comic book), Steve Ditko (Mar...
# 2      Jon Favreau  Mark Fergus (screenplay), Hawk Ostby (screenpl...
# 3  Kenneth Branagh  Ashley Miller (screenplay), Zack Stentz (scree...
#
#                                               Actors  \
# 0  Hugh Jackman, Patrick Stewart, Ian McKellen, F...
# 1  Tobey Maguire, Willem Dafoe, Kirsten Dunst, Ja...
# 2  Robert Downey Jr., Terrence Howard, Jeff Bridg...
# 3  Chris Hemsworth, Natalie Portman, Tom Hiddlest...
#
#                                                 Plot  ... Metascore  \
# 0  In a world where mutants (evolved super-powere...  ...        64
# 1  When bitten by a genetically modified spider, ...  ...        73
# 2  After being held captive in an Afghan cave, bi...  ...        79
# 3  The powerful but arrogant god Thor is cast out...  ...        57
#
#   imdbRating imdbVotes     imdbID   Type  DVD     BoxOffice  \
# 0        7.4   567,321  tt0120903  movie  N/A  $157,299,718
# 1        7.3   683,012  tt0145487  movie  N/A  $407,022,860
# 2        7.9   930,966  tt0371746  movie  N/A           N/A
# 3        7.0   740,509  tt0800369  movie  N/A  $181,030,624
#
#                                           Production Website Response
# 0  Twentieth Century Fox, Genetics Productions, B...     N/A     True
# 1             Marvel Films, Laura Ziskin Productions     N/A     True
# 2                      Marvel Enterprises, Paramount     N/A     True
# 3                                     Marvel Studios     N/A     True
#
# [4 rows x 25 columns]
